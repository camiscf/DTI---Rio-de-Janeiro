# %%
import geopandas as gpd

bairros = gpd.read_file('data/raw/Limite_de_Bairros.geojson')

# %%
print("Quantidade de polígonos:", len(bairros))
print("CRS:", bairros.crs)
print("Colunas:", list(bairros.columns))
print("Tipo de geometria:", bairros.geom_type.unique())
print("\nPrimeiros 5 nomes:")
print(bairros[['nome', 'regiao_adm']].head())
